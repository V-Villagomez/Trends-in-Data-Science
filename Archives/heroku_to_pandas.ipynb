# %%
import psycopg2
import sqlalchemy
import pandas as pd

from config import db_url

# %%
# Create connection to database
from sqlalchemy import create_engine
engine = create_engine(f'{db_url}')
connection = engine.connect()

# %%
# Reading SQL tables into dataframes
data_df = pd.read_sql('select * from data_clean', connection)

# %%
data_df.head()
# Out:
#    id                          job_title  rating  \
# 0   1              Senior Data Scientist     3.5
# 1   2  Data Scientist, Product Analytics     4.5
# 2   3               Data Science Manager     NaN
# 3   4             Director, Data Science     3.4
# 4   5                     Data Scientist     2.9
#
#                       company_name us_state             sector  avg_salary  \
# 0                      Hopper\n3.5       NY   Travel & Tourism    146000.0
# 1                     Noom US\n4.5       NY  Consumer Services    146000.0
# 2                         Decode_M       NY               None    146000.0
# 3  United Entertainment Group\n3.4       NY  Business Services    146000.0
# 4               IFG Companies\n2.9       NY          Insurance    146000.0
#
#    avg_size  company_founded        lat        lon us_state_name
# 0    1000.0           2007.0  43.299428 -74.217933      New York
# 1    5000.0           2008.0  43.299428 -74.217933      New York
# 2      50.0              NaN  43.299428 -74.217933      New York
# 3     200.0           2007.0  43.299428 -74.217933      New York
# 4     500.0           1985.0  43.299428 -74.217933      New York
