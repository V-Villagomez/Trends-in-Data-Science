# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
# from config import g_key
import plotly.express as px

# %%
choropleth_df = pd.read_csv("data/data_final.csv")

# %%
px.choropleth(choropleth_df,
              locations = "state",
              locationmode = "USA-states",
              hover_name="state",
              color = "avg_Salary", scope ="usa")

# %%
px.choropleth(choropleth_df,
              locations = "state",
              locationmode = "USA-states",
              hover_name="state",
              color = "Rating", scope ="usa")
